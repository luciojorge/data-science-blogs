# %% [markdown]
# <a href="https://colab.research.google.com/github/luciojorge/data-science-blogs/blob/master/C%C3%B3pia_de_Big_Data_009_Aula_02_MapReduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Instruções iniciais**
#
# *   Abra o link dos dados: https://tinyurl.com/bd009-gut
# *   Clique em "Adicionar ao Drive"

# %% [markdown]
# # I/O e comandos básicos

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/gut"
# Out:
# master_list.csv  small	txt

# %%
# !ls "/content/drive/My Drive/gut/small"
# Out:
# u-8celt10.txt  u-andvl11.txt  u-dtroy10.txt  u-kalec10.txt  u-poe5v10.txt

# %%
# !cat "/content/drive/My Drive/gut/small/u-8celt10.txt"
# Out:
# Project Gutenberg's Celtic Fairy Tales, by Joseph Jacobs (coll. & ed.)
#
# Copyright laws are changing all over the world. Be sure to check the
# copyright laws for your country before downloading or redistributing
# this or any other Project Gutenberg eBook.
#
# This header should be the first thing seen when viewing this Project
# Gutenberg file.  Please do not remove it.  Do not change or edit the
# header without written permission.
#
# Please read the "legal small print," and other information about the
# eBook and Project Gutenberg at the bottom of this file.  Included is
# important information about your specific rights and restrictions in
# how the file may be used.  You can also find out about how to make a
# donation to Project Gutenberg, and how to get involved.
#
#
# **Welcome To The World of Free Plain Vanilla Electronic Texts**
#
# **eBooks Readable By Both Humans and By Computers, Since 1971**
#
# *****These eBooks Were Prepared By Thousands of Volunteers!*****
#
#
# ...

# %%
# !cat "/content/drive/My Drive/gut/small/"*txt
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# in front of it there was a yard enclosed with large, round,
# pointed stakes, and seated inside the stakes he saw as many as
# three hundred maidens, working at different kinds of embroidery.
# Each one was sewing with golden thread and silk, as best she
# could.  But such was their poverty, that many of them wore no
# girdle, and looked slovenly, because so poor; and their garments
# were torn about their breasts and at the elbows, and their shifts
# were soiled about their necks.  Their necks were thin, and their
# faces pale with hunger and privation.  They see him, as he looks
# at them, and they weep, and are unable for some time to do
# anything or to raise their eyes from the ground, so bowed down
# they are with woe.  When he had contemplated them for a while, my
# lord Yvain turned about and moved toward the door; but the porter
# barred the way, and cried: "It is no use, fair master; you shall
# ...

# %%
# !ls /content/drive/My\ Drive/gut/small/*txt
# Out:
# '/content/drive/My Drive/gut/small/u-8celt10.txt'
# '/content/drive/My Drive/gut/small/u-andvl11.txt'
# '/content/drive/My Drive/gut/small/u-dtroy10.txt'
# '/content/drive/My Drive/gut/small/u-kalec10.txt'
# '/content/drive/My Drive/gut/small/u-poe5v10.txt'

# %%
# !ln -s "/content/drive/My Drive/gut/small" /content/

# %%
# !ls /content/small/
# Out:
# u-8celt10.txt  u-andvl11.txt  u-dtroy10.txt  u-kalec10.txt  u-poe5v10.txt

# %%
# !wc /content/small/u-8celt10.txt
# Out:
#   8835  77106 417757 /content/small/u-8celt10.txt

# %%
# !cat /content/small/u-8celt10.txt | grep "Gutenberg"
# Out:
# Project Gutenberg's Celtic Fairy Tales, by Joseph Jacobs (coll. & ed.)
# this or any other Project Gutenberg eBook.
# Gutenberg file.  Please do not remove it.  Do not change or edit the
# eBook and Project Gutenberg at the bottom of this file.  Included is
# donation to Project Gutenberg, and how to get involved.
# End of Project Gutenberg's Celtic Fairy Tales, by Joseph Jacobs (coll. & ed.)
# Project Gutenberg eBooks are often created from several printed
# The official release date of all Project Gutenberg eBooks is at
# Gutenberg, including how to donate, how to help produce our new
# announcement goes out in the Project Gutenberg Newsletter.
# Information about Project Gutenberg (one page)
# The Goal of Project Gutenberg is to Give Away 1 Trillion eBooks!
# The Project Gutenberg Literary Archive Foundation has been created
# to secure a future for Project Gutenberg into the next millennium.
# Project Gutenberg Literary Archive Foundation
# ...

# %%
# !cat /content/small/u-8celt10.txt | grep "Gutenberg" | wc
# Out:
#      25     232    1551

# %% [markdown]
# # Map

# %%
# %%file word_count_map.py

import sys
import re

for line in sys.stdin:
  # modifique o script para separar as palavras de cada linha
  print(line)
# Out:
# Writing word_count_map.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# She dressed up the butler's son, and she gives him to the giant by
#
# the hand. The giant had not gone far when he put the rod in his
#
# hand.
#
#
#
# "If thy father had that rod," says the giant, "what would he do with
#
# it?"
#
#
#
# "He would beat the dogs and the cats when they would be coming near
#
# the king's bottles and glasses."
#
#
#
# "Thou art the son of the butler," says the giant and dashed his
#
# brains out too. The giant returned in a very great rage and anger.
#
# The earth shook under the sole of his feet, and the castle shook and
#
# all that was in it.
#
#
#
# "OUT HERE WITH THY SON," says the giant, "or in a twinkling the
#
# stone that is highest in the dwelling will be the lowest." So they
#
# had to give the king's son to the giant.
#
#
#
# When they were gone a little bit from the earth, the giant showed
#
# him the rod that was in his hand and said: "What would thy father do
#
# ...

# %% [markdown]
# **Pare aqui!**
#
# Implemente a sua solução antes de continuar
#
# ![960600.jpg](data:image/jpeg;base64,...)

# %%
# %%file word_count_map_simples.py

import sys

for line in sys.stdin:
  line = line.lower()
  for word in line.split() :
    print(word+"\t"+str(1))
# Out:
# Writing word_count_map_simples.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map_simples.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# others	1
# is	1
# peculiarly	1
# buddhistic;	1
# the	1
# "hare	1
# in	1
# the	1
# moon"	1
# is	1
# an	1
# apotheosis	1
# of	1
# such	1
# a	1
# piece	1
# of	1
# self-sacrifice	1
# on	1
# the	1
# part	1
# of	1
# buddha	1
# (_sasa	1
# jataka_).	1
# there	1
# are	1
# two	1
# forms	1
# that	1
# have	1
# reached	1
# the	1
# west,	1
# the	1
# first	1
# being	1
# that	1
# of	1
# an	1
# animal	1
# saving	1
# men	1
# at	1
# the	1
# cost	1
# of	1
# its	1
# own	1
# life.	1
# i	1
# pointed	1
# out	1
# an	1
# early	1
# instance	1
# of	1
# this,	1
# quoted	1
# by	1
# a	1
# rabbi	1
# of	1
# the	1
# second	1
# century,	1
# in	1
# my	1
# _fables	1
# of	1
# aesop_,	1
# i.	1
# 105.	1
# this	1
# concludes	1
# with	1
# a	1
# strangely	1
# close	1
# parallel	1
# to	1
# gellert;	1
# "they	1
# raised	1
# a	1
# cairn	1
# over	1
# his	1
# grave,	1
# and	1
# the	1
# place	1
# is	1
# still	1
# called	1
# the	1
# dog's	1
# grave."	1
# the	1
# _culex_	1
# ...

# %%
# %%file word_count_map_ineficiente.py

import sys

for line in sys.stdin:
  line = line.lower()
  for char in '`~!@#$%^&*()_-+=/*-,./<>?;:\'\"[]{}|0123456789\'\"' :
    line = line.replace(char, ' ')

  for word in line.split() :
    print(word+"\t"+str(1))
# Out:
# Writing word_count_map_ineficiente.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map_ineficiente.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# reached	1
# the	1
# west	1
# the	1
# first	1
# being	1
# that	1
# of	1
# an	1
# animal	1
# saving	1
# men	1
# at	1
# the	1
# cost	1
# of	1
# its	1
# own	1
# life	1
# i	1
# pointed	1
# out	1
# an	1
# early	1
# instance	1
# of	1
# this	1
# quoted	1
# by	1
# a	1
# rabbi	1
# of	1
# the	1
# second	1
# century	1
# in	1
# my	1
# fables	1
# of	1
# aesop	1
# i	1
# this	1
# concludes	1
# with	1
# a	1
# strangely	1
# close	1
# parallel	1
# to	1
# gellert	1
# they	1
# raised	1
# a	1
# cairn	1
# over	1
# his	1
# grave	1
# and	1
# the	1
# place	1
# is	1
# still	1
# called	1
# the	1
# dog	1
# s	1
# grave	1
# the	1
# culex	1
# attributed	1
# to	1
# virgil	1
# seems	1
# to	1
# be	1
# another	1
# variant	1
# of	1
# this	1
# the	1
# second	1
# form	1
# of	1
# the	1
# legend	1
# is	1
# always	1
# told	1
# as	1
# a	1
# moral	1
# apologue	1
# against	1
# precipitate	1
# action	1
# and	1
# originally	1
# occurred	1
# in	1
# the	1
# fables	1
# ...

# %%
# %%file word_count_map.py

import sys
import re

for line in sys.stdin:
  line = re.sub('[^a-z ]', '', line.lower())
  for word in line.split() :
    print(word+"\t"+str(1))
# Out:
# Overwriting word_count_map.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# is	1
# well	1
# known	1
# and	1
# has	1
# been	1
# elaborately	1
# discussed	1
# by	1
# mr	1
# baringgould	1
# curious	1
# myths	1
# of	1
# the	1
# middle	1
# ages	1
# p	1
# seq	1
# and	1
# mr	1
# w	1
# a	1
# clouston	1
# popular	1
# tales	1
# and	1
# fictions	1
# ii	1
# seq	1
# the	1
# story	1
# of	1
# the	1
# man	1
# who	1
# rashly	1
# slew	1
# the	1
# dog	1
# ichneumon	1
# weasel	1
# c	1
# that	1
# had	1
# saved	1
# his	1
# babe	1
# from	1
# death	1
# is	1
# one	1
# of	1
# those	1
# which	1
# have	1
# spread	1
# from	1
# east	1
# to	1
# west	1
# it	1
# is	1
# indeed	1
# as	1
# mr	1
# clouston	1
# points	1
# out	1
# still	1
# current	1
# in	1
# india	1
# the	1
# land	1
# of	1
# its	1
# birth	1
# there	1
# is	1
# little	1
# doubt	1
# that	1
# it	1
# is	1
# originally	1
# buddhistic	1
# the	1
# late	1
# prof	1
# s	1
# beal	1
# gave	1
# the	1
# earliest	1
# known	1
# version	1
# from	1
# the	1
# chinese	1
# translation	1
# ...

# %%
# !echo "big data is big" | python3 word_count_map.py | sort
# Out:
# big	1
# big	1
# data	1
# is	1

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py | sort
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# ...

# %% [markdown]
# # Reduce

# %%
# %%file count_reduce.py

import sys

current = ''
count = 0

for line in sys.stdin:
  word, value = line.split('\t')
  count = int(value)
  if word == current :
    #é a mesma palavra
    total = total + count
  else :
    # é uma palavra diferente
    if current != '':
     print(current+"\t"+str(total))
    curent = word
    total = count 

  # modifique a saída para contar todas as ocorrências de uma palavra
  print(word+"\t"+str(count))
# Out:
# Overwriting count_reduce.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py | sort | python3 count_reduce.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# were	1
# ...

# %% [markdown]
# **Pare aqui!**
#
# Implemente a sua solução antes de continuar
#
# ![image.png](data:image/png;base64,...)

# %%
# %%file count_reduce.py

import sys

current_word = None
count_count = 0

for line in sys.stdin:
  word, value = line.split('\t')
  count = int(value)
  if current_word != word :
    # se a palavra de entrada é diferente da palavra sendo contada
    if current_word :
      # se a palavra sendo contada não é nula
      print(current_word+"\t"+str(count_count))
    # muda a palavra sendo contada
    current_word = word
    count_count = count
  else :
    # se a palavra de entrada é a mesma que está sendo contada
    count_count = count_count + count

# imprime a última palavra
if current_word :
  print(current_word+"\t"+str(count_count))
# Out:
# Overwriting count_reduce.py

# %%
# !echo "big data is big" | python3 word_count_map.py | sort | python3 count_reduce.py
# Out:
# big	2
# data	1
# is	1

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py | sort | python3 count_reduce.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# etymologising	1
# etymology	4
# euphemise	1
# europe	13
# european	12
# even	25
# evening	16
# event	2
# events	3
# ever	76
# everliving	1
# evermore	1
# every	74
# everybody	6
# everybodys	1
# everything	11
# everywhere	1
# everywherenorth	1
# evidence	3
# evil	2
# evolved	1
# exact	3
# exactly	3
# example	2
# examples	3
# exceed	1
# exceeded	1
# exceedingly	1
# exceeds	1
# excellent	1
# except	11
# excessive	1
# exchange	1
# exchanging	1
# excising	1
# exclaimed	1
# exclusion	1
# exclusions	1
# excursuses	1
# exeter	1
# exhausting	1
# exhaustion	1
# exist	2
# existed	3
# existence	7
# exists	2
# expect	1
# expectation	1
# expected	1
# expectedfor	1
# expedition	1
# expended	1
# expends	1
# expense	3
# expenses	1
# experience	1
# explain	4
# explained	1
# explanatory	1
# exploit	2
# exploits	1
# exportations	1
# express	2
# expression	1
# extant	3
# extend	2
# extends	1
# extent	7
# extenuated	1
# external	3
# extinct	2
# ...

# %%
# %%file count_reduce_dict.py

import sys

totals = {}

for line in sys.stdin:
  word, value = line.split('\t')
  count = int(value)
  try:
    totals[word] = totals[word]+count
  except:
    totals[word] = count

for word in totals.keys():
  print(word+"\t"+str(totals[word]))
# Out:
# Writing count_reduce_dict.py

# %%
# !cat /content/small/u-8celt10.txt | python3 word_count_map.py | sort | python3 count_reduce_dict.py
# Out:
# a	1532
# ab	2
# abbey	4
# abergarwan	1
# abergavenny	1
# abhorred	1
# able	22
# abode	3
# about	105
# above	17
# abraham	2
# abridged	3
# abroad	8
# absence	6
# abstract	1
# abstracted	1
# abuse	2
# abwy	1
# academy	2
# accept	4
# accepted	1
# accepting	1
# accepts	1
# accidental	1
# accompanied	1
# accompanying	1
# accomplished	1
# according	13
# accordingly	8
# account	11
# accounts	1
# accrue	1
# accumulated	1
# accuracy	1
# ach	2
# ache	1
# achieve	2
# achieving	1
# acorn	1
# acquainted	2
# acre	1
# acres	1
# across	10
# act	1
# action	3
# active	3
# activity	1
# acts	1
# acushla	1
# ad	2
# adaptation	2
# adapting	1
# add	4
# added	10
# adder	1
# adders	1
# addition	1
# additional	5
# additions	2
# address	2
# addressed	1
# addresses	1
# adds	1
# adherence	1
# adjacent	1
# adjured	1
# admirable	1
# admit	1
# admixture	1
# adopted	5
# adoption	1
# advance	2
# adventure	6
# adventures	6
# advice	9
# advices	1
# advise	1
# advocates	1
# aer	2
# aesop	2
# affection	1
# affections	1
# ...

# %%
drive.flush_and_unmount()
